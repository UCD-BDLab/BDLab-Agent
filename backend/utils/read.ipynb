# %%
import pandas as pd

def read_policy(file_path):
    """
    Reads a policy CSV file and returns its contents as a list of dictionaries.
    
    Args:
        file_path (str): The path to the CSV file.
        
    Returns:
        List[Dict]: A list of dictionaries representing the rows in the CSV file.
    """
    df = pd.read_csv(file_path, dtype=str,index_col=0)
    df["document_name"] = ""
    #print(df.columns)
    for idx, row in df.iterrows():
        df.loc[idx,"document_name"] = f"{row['state']}_{row['Bill.Type']}_{row['Number']}_{row['year']}"
    return df

policies = read_policy('/home/vicente/Github/BDLab-Agent/backend/DISES/CodingResults.csv')
display(policies)
# Out:
#     state Bill.Type Number  year  sess_year  \
# 1      AK         S    205  2024       2024
# 2      AZ         H   2720  2024       2024
# 3      AZ         H   2721  2024       2024
# 4      AZ         S   1415  2024       2024
# 5      CA         A   2345  2020  2019-2020
# ..    ...       ...    ...   ...        ...
# 271    WA         S   5746  2020  2019-2020
# 272    WA         S   5466  2023  2023-2024
# 273    WA         S   6173  2024  2023-2024
# 274    WV         H   4502  2022       2022
# 275    WV         S    686  2022       2022
#
#                                                  codes   document_name
# 1    Land Acquisition, Specific Location, Authoriza...   AK_S_205_2024
# 2    As of Right, Zoning, Urban, Local Gov, Require...  AZ_H_2720_2024
# 3    Time of Adoption, Requirement, Urban, Zoning, ...  AZ_H_2721_2024
# 4    Specific Location, Urban, Requirement, ADU, Si...  AZ_S_1415_2024
# 5    State Gov, Requirement, Reporting,Local Gov, R...  CA_A_2345_2020
# ..                                                 ...             ...
# 271  Affordable, Low-Income, Requirement, State Gov...  WA_S_5746_2020
# 272  Definition, Floor Area Ratio,NA, Transit Zones...  WA_S_5466_2023
# 273  Affordable, Income Specification, Local Gov, I...  WA_S_6173_2024
# 274  Definition,Reporting, Increasing Tax Credits, ...  WV_H_4502_2022
# 275  State Gov, Authorization, Increasing Loan Acce...   WV_S_686_2022
#
# [275 rows x 7 columns]

# %%
#display(policies)
results = pd.read_csv('/home/vicente/Github/BDLab-Agent/backend/DISES/DISES-policy-coding-quotations.csv', dtype=str)
print(results.columns)

def find_overlap(policies, results):
    rows = []

    for _, row in results.iterrows():
        doc = row.get("document")
        if doc is None:
            continue
        doc = str(doc)

        if not doc.endswith("Emma.pdf"):
            continue

        if doc.endswith(".pdf"):
            doc = doc[:-4]

        if doc.endswith("_Emma"):
            doc = doc[:-5]

        document_name = doc.replace(" ", "_").replace("-", "_")

        raw_codes = str(row.get("codes", ""))
        codes_list = []
        for part in raw_codes.split(","):
            part = part.strip()
            if part:
                codes_list.append(part)

        out = {
            "document_name": document_name,
            "query": row.get("quotation", ""),
            "codes": codes_list,
        }
        rows.append(out)

    if len(rows) == 0:
        return pd.DataFrame(columns=["document_name", "query", "codes"])

    return pd.DataFrame(rows)

overlap = find_overlap(policies, results)
# Out:
# Index(['document', 'quotation', 'codes', 'comment'], dtype='object')

# %%
display(overlap)
# Out:
#     document_name                                              query  \
# 0    CA_S_20_1400  This bill would enact the Accessory Dwelling U...
# 1    CA_S_20_1400  This bill would provide for submission of the ...
# 2    CA_S_20_1400  SEC. 3. Section 1 of this act shall be submitt...
# 3    CA_S_20_1400  (a) To make and execute contracts and all othe...
# 4    CA_S_20_1400  d) To provide advice, technical information, a...
# ..            ...                                                ...
# 307  CA_AB_20_434  987.010. (a) For any loans issued pursuant to ...
# 308  CA_AB_20_434  (b) All moneys received by the department in r...
# 309  CA_AB_20_434  (f) All moneys set aside for the default reser...
# 310  CA_AB_20_434  (h) This section shall remain in effect only u...
# 311  CA_AB_20_434  (h) This section shall become operative on Jan...
#
#                                                  codes
# 0    [ADU, Homeowners, Budget Amount Allocated, Inc...
# 1                                   [Voter Referendum]
# 2                                   [Voter Referendum]
# 3                                                [nan]
# 4                               [Technical Assistance]
# ..                                                 ...
# 307  [Increasing Loan Access, Developers, Veterans,...
# 308  [Increasing Funding, Increasing Loan Access, D...
# 309  [Increasing Loan Access, Increasing Funding, D...
# 310                                           [Repeal]
# 311                                 [Time of Adoption]
#
# [312 rows x 3 columns]

# %%
overlap.to_csv('/home/vicente/Github/BDLab-Agent/backend/utils/overlap.csv', index=False)
